# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = sns.load_dataset('tips')
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(data=data,x = 'day', y = 'tip',estimator='median',hue='sex',order=['Sun','Sat','Fri','Thur'] , palette=['green','blue'],errorbar=['ci',0])
plt.legend(ncols=2)
plt.grid(linestyle='--')
plt.show()

# %%
sns.barplot(data=d, x='sex', y='time', hue='smoker', palette='viridis')

plt.title("Count of Time by Sex and Smoker")
plt.ylabel("Count")
plt.grid(True)
plt.show()

# %%
d = data.groupby(['sex','smoker'])['time'].count().reset_index()
sns.barplot(data=d, x='sex', y='time', hue='smoker', palette='viridis',estimator='median',order = ['Female','Male'])
plt.grid(True)
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_628\4266219685.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   d = data.groupby(['sex','smoker'])['time'].count().reset_index()
